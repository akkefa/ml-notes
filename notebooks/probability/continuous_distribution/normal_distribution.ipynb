# %%
x <- seq(-10, 10, by = .1)

# %% [markdown]
# ## dnorm()
# This function gives height of the probability distribution at each point for a given mean and standard deviation.

# %%
y = dnorm(x, mean = 0, sd = 1)
plot(x, y, type="l")
# Out:
# plot without title

# %% [markdown]
# ## pnorm()
# This function gives the probability of a normally distributed random number to be less that the value of a given number. It is also called "Cumulative Distribution Function".

# %%
y <- pnorm(x, mean = 0, sd = 1)
plot(x,y, type="l")
# Out:
# plot without title

# %% [markdown]
# ## qnorm()
# This function takes the probability value and gives a number whose cumulative value matches the probability value.

# %%
# Create a sequence of probability values incrementing by 0.02.
x <- seq(0, 1, by = 0.02)
y <- qnorm(x, mean = 0, sd = 1)
# Plot the graph.
plot(x,y)

dnorm(10, 0 ,1)
pnorm(2)
qnorm(0.977249868,0,1)
# Out:
# [1] 7.694599e-23
# [1] 0.9772499
# [1] 2
# plot without title

# %%
# find P(Z > 1.25) = 1 - P(Z < 1.25)
1 -pnorm(2)
# Out:
# [1] 0.02275013

# %%
# find P (-3.8 < Z < 1.25) = find roc from -3.8 to 1.25 
# = p(Z < 1.25) - p(Z < -3.8)
pnorm(1.25) - pnorm(-3.8)
# Out:
# [1] 0.8942779

# %%
#Let XX be a normal random variable with mean 00 and variance 11. That is, X \sim N(0,1)X∼N(0,1).
#Given that P(|X|<2) \approx 0.9545P(∣X∣<2)≈0.9545, what is the probability that X>2?

# We need to find the Z-score greater then 2. So P(X > 2) = 1 - p( X < 2)

1 - pnorm(2)
# Out:
# [1] 0.02275013
